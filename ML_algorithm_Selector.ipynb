# %% [markdown]
# <a href="https://colab.research.google.com/github/theHoodguy4587/ML-alogrithm-selector/blob/main/ML_algorithm_Selector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/meta-dataset.csv")
df.head(10)
# Out:
#      did  n_samples  n_features  imbalance_ratio  avg_corr     class_sep  \
# 0  45570      25000          28         0.887077  0.068817  2.816869e-01
# 1  45689      25000          14         0.330920  0.000000  1.404195e+03
# 2  45660      25000           8         0.735027  0.195759  4.019202e-01
# 3  45656      25000          14         0.330849  0.000000           NaN
# 4  45654      25000          20         0.999680  0.005274  1.246352e+00
# 5  45703      25000          16         0.131529  0.000000  1.026344e+03
# 6  45704      25000          10         0.999200  0.186239  5.817236e-01
# 7  45693      25000           8         0.735027  0.195759  4.019202e-01
# 8  42732      25000           8         0.138434  0.000000  6.502751e+02
# 9   1218      25000          11         0.200077  0.099968  9.501430e+16
#
#             best_algo
# 0                 SVC
# 1  LogisticRegression
# 2        DecisionTree
# 3        DecisionTree
# 4  LogisticRegression
# 5  LogisticRegression
# ...

# %%
df.describe()
# Out:
#                 did     n_samples  n_features  imbalance_ratio    avg_corr  \
# count    728.000000    728.000000  728.000000       728.000000  702.000000
# mean   25956.840659   7201.842033   17.552198         0.642212    0.106337
# std    21423.105379   9442.759453   11.339455         0.348551    0.159374
# min        3.000000    195.000000    2.000000         0.000000    0.000000
# 25%      950.750000    879.750000    8.000000         0.312719    0.000000
# 50%    43897.500000   2000.000000   14.000000         0.785714    0.009384
# 75%    44460.250000  10578.000000   24.000000         1.000000    0.157443
# max    46568.000000  25000.000000   48.000000         1.000000    0.775321
#
#           class_sep
# count  6.310000e+02
# mean   3.580464e+15
# std    3.018750e+16
# min    1.053543e-02
# 25%    1.304660e+00
# 50%    4.997712e+01
# 75%    9.526972e+02
# max    4.359531e+17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   did              728 non-null    int64
#  1   n_samples        728 non-null    int64
#  2   n_features       728 non-null    int64
#  3   imbalance_ratio  728 non-null    float64
#  4   avg_corr         702 non-null    float64
#  5   class_sep        631 non-null    float64
#  6   best_algo        728 non-null    object
# dtypes: float64(3), int64(3), object(1)
# memory usage: 39.9+ KB

# %%
df.isnull().sum()
# Out:
# did                 0
# n_samples           0
# n_features          0
# imbalance_ratio     0
# avg_corr           26
# class_sep          97
# best_algo           0
# dtype: int64

# %%
df['best_algo'].value_counts()
# Out:
# best_algo
# DecisionTree          294
# LogisticRegression    285
# SVC                   149
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (728, 7)

# %%
df['avg_corr']=pd.to_numeric(df['avg_corr'],errors='coerce').fillna(df['avg_corr'].median())

# %%
df['class_sep']=pd.to_numeric(df['class_sep'],errors='coerce').fillna(df['class_sep'].median())

# %%
df.isnull().sum()
# Out:
# did                0
# n_samples          0
# n_features         0
# imbalance_ratio    0
# avg_corr           0
# class_sep          0
# best_algo          0
# dtype: int64

# %%
X=df[['n_samples','n_features','imbalance_ratio','avg_corr','class_sep']]
y=df['best_algo']

# %% [markdown]
# Encode the target variable

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
y_encoded=le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

model=RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
# Out:
#      n_samples  n_features  imbalance_ratio  avg_corr     class_sep
# 433       2000          30         0.795332  0.000000      1.363729
# 136      25000           7         0.805836  0.000000    186.508730
# 350       2000          17         1.000000  0.000000    158.274780
# 6        25000          10         0.999200  0.186239      0.581724
# 318       2000          48         0.329787  0.009384    174.225880
# ..         ...         ...              ...       ...           ...
# 71       25000          37         0.037818  0.000000     49.977123
# 106      25000          13         0.285744  0.000000  26042.740000
# 270       2351          46         0.786474  0.000000      5.310941
# 435       2000          30         0.795332  0.000000      1.393710
# 102      25000          16         0.132503  0.000000    617.131100
#
# [582 rows x 5 columns]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
y_pred=model.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy:{accuracy}")
# Out:
# Accuracy:0.7808219178082192
